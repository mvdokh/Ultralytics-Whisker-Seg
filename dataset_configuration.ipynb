# %%
import os
from dataset_utils import remove_img_prefix, list_img_files

# Define the root directory - using WSL path to access Windows Desktop
root_directory = "/mnt/c/Users/wanglab/Desktop/Whisker_Training_Data"

# First, let's check what files we have with 'img' prefix
print("Checking for files with 'img' prefix...")
img_files = list_img_files(root_directory)

if img_files:
    print(f"Found {len(img_files)} files with 'img' prefix:")
    for file_path in img_files[:10]:  # Show first 10 files
        print(f"  {file_path}")
    if len(img_files) > 10:
        print(f"  ... and {len(img_files) - 10} more files")
else:
    print("No files with 'img' prefix found")
    print(f"Please check if the directory exists: {root_directory}")
    if os.path.exists(root_directory):
        print("Directory exists, but no 'img' files found in subdirectories")
    else:
        print("Directory does not exist - please verify the path")
# Out:
# Checking for files with 'img' prefix...
# Found 21666 files with 'img' prefix:
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0000000.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0000001.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011004.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011007.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011036.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011122.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011143.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011256.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011570.png
#   /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images/img0011649.png
#   ... and 21656 more files

# %%
# ACTUAL RENAME OPERATION
actual_summary = remove_img_prefix(root_directory, dry_run=False)
# Out:
# Processing images folder: /mnt/c/Users/wanglab/Desktop/Whisker_Training_Data/0110_1/images
#   Renamed: img0000000.png -> 0000000.png
#   Renamed: img0000001.png -> 0000001.png
#   Renamed: img0011004.png -> 0011004.png
#   Renamed: img0011007.png -> 0011007.png
#   Renamed: img0011036.png -> 0011036.png
#   Renamed: img0011122.png -> 0011122.png
#   Renamed: img0011143.png -> 0011143.png
#   Renamed: img0011256.png -> 0011256.png
#   Renamed: img0011570.png -> 0011570.png
#   Renamed: img0011649.png -> 0011649.png
#   Renamed: img0011650.png -> 0011650.png
#   Renamed: img0011651.png -> 0011651.png
#   Renamed: img0011720.png -> 0011720.png
#   Renamed: img0011733.png -> 0011733.png
#   Renamed: img0012158.png -> 0012158.png
#   Renamed: img0012547.png -> 0012547.png
#   Renamed: img0012635.png -> 0012635.png
#   Renamed: img0012636.png -> 0012636.png
#   Renamed: img0012691.png -> 0012691.png
#   Renamed: img0012692.png -> 0012692.png
#   Renamed: img0012719.png -> 0012719.png
# ...

# %%
from csv_to_ultralytics_enhanced_utils import csv_to_ultralytics_enhanced
output_path = csv_to_ultralytics_enhanced("/mnt/c/Users/wanglab/Desktop/Whisker_Tracking_Data")
